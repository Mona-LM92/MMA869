# %%
import pandas as pd
import numpy as np

train_s = pd.read_csv("pc1_small_train_data_v1.csv")
train_m = pd.read_csv("pc1_medium_train_data_v1.csv")
train_l = pd.read_csv("pc1_large_train_data_v1.csv")
test = pd.read_csv("pc1_test_without_response_variable_data_v1.csv")

# %%
test.describe()
# Out:
#        price  city_fuel_economy  engine_displacement  highway_fuel_economy  \
# count    0.0       20000.000000         20000.000000          20000.000000
# mean     NaN          23.586900          2545.595000             31.214400
# std      NaN           6.288181           975.577359              6.260215
# min      NaN           9.000000           700.000000             12.000000
# 25%      NaN          19.000000          2000.000000             27.000000
# 50%      NaN          24.000000          2400.000000             31.000000
# 75%      NaN          27.000000          3200.000000             36.000000
# max      NaN          81.000000          8100.000000             86.000000
#
#          horsepower        mileage          year
# count  20000.000000   20000.000000  20000.000000
# mean     206.151250   59219.647300   2015.868350
# std       64.811139   36322.410902      2.902902
# min       78.000000   10000.000000   1984.000000
# ...

# %%
train_s.describe()
# Out:
#               price  city_fuel_economy  engine_displacement  \
# count  30000.000000       30000.000000         30000.000000
# mean   15665.107960          23.563467          2545.056667
# std     2713.340955           6.174699           973.024044
# min    10000.000000           9.000000           700.000000
# 25%    13506.750000          19.000000          2000.000000
# 50%    15969.000000          23.000000          2400.000000
# 75%    17988.000000          27.000000          3000.000000
# max    19999.000000          81.000000          7400.000000
#
#        highway_fuel_economy    horsepower        mileage          year
# count          30000.000000  30000.000000   30000.000000  30000.000000
# mean              31.186600    205.702933   59647.691233   2015.822067
# std                6.187675     64.686119   36816.818992      2.990157
# min               10.000000     78.000000   10003.000000   1984.000000
# ...

# %%
train_s.head()
# Out:
#      price  city_fuel_economy  engine_displacement  highway_fuel_economy  \
# 0  16991.0                 17                 3600                    25
# 1  16950.0                 15                 5000                    21
# 2  11342.0                 16                 4000                    22
# 3  13488.0                 29                 1800                    37
# 4  18994.0                 28                 2000                    37
#
#    horsepower  mileage  year
# 0         283    47706  2018
# 1         360    67250  2014
# 2         261   129241  2013
# 3         124    39854  2018
# 4         147    30297  2017

# %%
train_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   price                 30000 non-null  float64
#  1   city_fuel_economy     30000 non-null  int64
#  2   engine_displacement   30000 non-null  int64
#  3   highway_fuel_economy  30000 non-null  int64
#  4   horsepower            30000 non-null  int64
#  5   mileage               30000 non-null  int64
#  6   year                  30000 non-null  int64
# dtypes: float64(1), int64(6)
# memory usage: 1.6 MB

# %%
train_m.describe()
# Out:
#               price  city_fuel_economy  engine_displacement  \
# count  50000.000000        50000.00000         50000.000000
# mean   39050.902945           17.65736          3967.606000
# std     8336.411789            3.71604          1274.230945
# min    30002.000000            8.00000           700.000000
# 25%    32997.000000           16.00000          3000.000000
# 50%    36590.000000           17.00000          3600.000000
# 75%    42000.000000           19.00000          5300.000000
# max    80000.000000           70.00000          8400.000000
#
#        highway_fuel_economy    horsepower       mileage          year
# count          50000.000000  50000.000000  5.000000e+04  50000.000000
# mean              24.024440    338.383760  3.290581e+04   2017.686580
# std                4.106772     68.641679  2.635795e+04      1.782967
# min               12.000000     95.000000  1.000000e+04   1984.000000
# 25%               22.000000    285.000000  1.989100e+04   2017.000000
# ...

# %%
train_m.head()
# Out:
#      price  city_fuel_economy  engine_displacement  highway_fuel_economy  \
# 0  31409.0                 15                 5700                    21
# 1  33000.0                 16                 5300                    22
# 2  31900.0                 16                 3600                    20
# 3  32980.0                 18                 3600                    25
# 4  33999.0                 15                 3500                    19
#
#    horsepower  mileage  year
# 0         395    26054  2017
# 1         355    45804  2017
# 2         285    24653  2016
# 3         310    41538  2017
# 4         365    62268  2017

# %%
train_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   price                 50000 non-null  float64
#  1   city_fuel_economy     50000 non-null  int64
#  2   engine_displacement   50000 non-null  int64
#  3   highway_fuel_economy  50000 non-null  int64
#  4   horsepower            50000 non-null  int64
#  5   mileage               50000 non-null  int64
#  6   year                  50000 non-null  int64
# dtypes: float64(1), int64(6)
# memory usage: 2.7 MB

# %%
train_l.describe()
# Out:
#                price  city_fuel_economy  engine_displacement  \
# count  100000.000000      100000.000000        100000.000000
# mean    43596.157796          17.275780          4137.848000
# std      8242.828486           3.814442          1337.606452
# min     35001.000000           8.000000           700.000000
# 25%     37790.000000          15.000000          3000.000000
# 50%     40900.000000          17.000000          3600.000000
# 75%     46950.000000          19.000000          5300.000000
# max     80000.000000          74.000000          8400.000000
#
#        highway_fuel_economy     horsepower       mileage           year
# count         100000.000000  100000.000000  1.000000e+05  100000.000000
# mean              23.434410     356.939770  3.059939e+04    2017.856140
# std                4.097285      71.229815  2.241080e+04       1.898526
# min               12.000000      82.000000  1.000000e+04    1984.000000
# ...

# %%
train_l.head()
# Out:
#      price  city_fuel_economy  engine_displacement  highway_fuel_economy  \
# 0  39800.0                 15                 6400                    25
# 1  45000.0                 17                 3600                    23
# 2  41888.0                 16                 5300                    23
# 3  40000.0                 22                 2000                    27
# 4  39963.0                 20                 3000                    29
#
#    horsepower  mileage  year
# 0         485    46760  2016
# 1         276    18672  2019
# 2         355    32864  2017
# 3         241    23992  2018
# 4         335    43591  2017

# %%
train_l.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   price                 100000 non-null  float64
#  1   city_fuel_economy     100000 non-null  int64
#  2   engine_displacement   100000 non-null  int64
#  3   highway_fuel_economy  100000 non-null  int64
#  4   horsepower            100000 non-null  int64
#  5   mileage               100000 non-null  int64
#  6   year                  100000 non-null  int64
# dtypes: float64(1), int64(6)
# memory usage: 5.3 MB

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score



# Define the features and target variable
X = train_s.drop(columns=['price'])
y = np.log(train_s['price'])

# Split the data into train and test sets (80/20 split)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# Initialize the models
linear = LinearRegression()
lasso = Lasso()
ridge = Ridge()
decision_tree = DecisionTreeRegressor()

# Train the model
linear.fit(X_train, y_train)
lasso.fit(X_train, y_train)
ridge.fit(X_train, y_train)
decision_tree.fit(X_train, y_train)

# Make predictions
y_pred_linear = linear.predict(X_test)
y_pred_lasso = lasso.predict(X_test)
y_pred_ridge = ridge.predict(X_test)
y_pred_tree = decision_tree.predict(X_test)

# Calculate performance metrics
mse_linear = mean_squared_error(y_test, y_pred_linear)
r2_linear = r2_score(y_test, y_pred_linear)

mse_lasso = mean_squared_error(y_test, y_pred_lasso)
r2_lasso = r2_score(y_test, y_pred_lasso)

mse_ridge = mean_squared_error(y_test, y_pred_ridge)
r2_ridge = r2_score(y_test, y_pred_ridge)

mse_tree = mean_squared_error(y_test, y_pred_tree)
r2_tree = r2_score(y_test, y_pred_tree)

# Print the performance metrics
mse_linear, r2_linear, mse_lasso, r2_lasso, mse_ridge, r2_ridge, mse_tree, r2_tree
# Out:
# (0.01939809297094917,
#  0.4206801935075456,
#  0.02382447197589612,
#  0.28848735205408715,
#  0.019398094936347227,
#  0.42068013481136224,
#  0.01995483104923545,
#  0.4040533324927639)

# %%
# Define the features and target variable
X_m = train_m.drop(columns=['price'])
y_m = np.log(train_m['price'])

# Split the data into train and test sets (80/20 split)
X_train_m, X_test_m, y_train_m, y_test_m =  train_test_split(X_m, y_m, test_size=0.2, random_state=123)

# Train the model
linear.fit(X_train_m, y_train_m)
lasso.fit(X_train_m, y_train_m)
ridge.fit(X_train_m, y_train_m)
decision_tree.fit(X_train_m, y_train_m)

# Make predictions
y_pred_linear_m = linear.predict(X_test_m)
y_pred_lasso_m = lasso.predict(X_test_m)
y_pred_ridge_m = ridge.predict(X_test_m)
y_pred_tree_m = decision_tree.predict(X_test_m)

# Calculate performance metrics
mse_linear_m = mean_squared_error(y_test_m, y_pred_linear_m)
r2_linear_m = r2_score(y_test_m, y_pred_linear_m)

mse_lasso_m = mean_squared_error(y_test_m, y_pred_lasso_m)
r2_lasso_m = r2_score(y_test_m, y_pred_lasso_m)

mse_ridge_m = mean_squared_error(y_test_m, y_pred_ridge_m)
r2_ridge_m = r2_score(y_test_m, y_pred_ridge_m)

mse_tree_m = mean_squared_error(y_test_m, y_pred_tree_m)
r2_tree_m = r2_score(y_test_m, y_pred_tree_m)



# Print the performance metrics
mse_linear_m, r2_linear_m, mse_lasso_m, r2_lasso_m, mse_ridge_m, r2_ridge_m, mse_tree_m, r2_tree_m
# Out:
# (0.023687266799032394,
#  0.3259273488974055,
#  0.025472502260132198,
#  0.27512459439155146,
#  0.023687265372103042,
#  0.3259273895037811,
#  0.016692257053645645,
#  0.5249855519212319)

# %%
# Define the features and target variable
X_l = train_l.drop(columns=['price'])
y_l = np.log(train_l['price'])

# Split the data into train and test sets (80/20 split)
X_train_l, X_test_l, y_train_l, y_test_l = train_test_split(X_l, y_l, test_size=0.2, random_state=123)


# Train the model
linear.fit(X_train_l, y_train_l)
lasso.fit(X_train_l, y_train_l)
ridge.fit(X_train_l, y_train_l)
decision_tree.fit(X_train_l, y_train_l)

# Make predictions
y_pred_linear_l = linear.predict(X_test_l)
y_pred_lasso_l = lasso.predict(X_test_l)
y_pred_ridge_l = ridge.predict(X_test_l)
y_pred_tree_l = decision_tree.predict(X_test_l)

# Calculate performance metrics
mse_linear_l = mean_squared_error(y_test_l, y_pred_linear_l)
r2_linear_l = r2_score(y_test_l, y_pred_linear_l)

mse_lasso_l = mean_squared_error(y_test_l, y_pred_lasso_l)
r2_lasso_l = r2_score(y_test_l, y_pred_lasso_l)

mse_ridge_l = mean_squared_error(y_test_l, y_pred_ridge_l)
r2_ridge_l = r2_score(y_test_l, y_pred_ridge_l)

mse_tree_l = mean_squared_error(y_test_l, y_pred_tree_l)
r2_tree_l = r2_score(y_test_l, y_pred_tree_l)

# Print the performance metrics
mse_linear_l, r2_linear_l, mse_lasso_l, r2_lasso_l, mse_ridge_l, r2_ridge_l, mse_tree_l, r2_tree_l
# Out:
# (0.020751195103744634,
#  0.2643808233377408,
#  0.02161087223418647,
#  0.23390571191744114,
#  0.02075119525587796,
#  0.2643808179446928,
#  0.013519241220231367,
#  0.5207498630413601)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Combine train and test sets with a new column indicating the set
X_train['set'] = 'train'
X_test['set'] = 'test'

# Concatenate the data
combined = pd.concat([X_train, X_test])

# Plot the distribution of features
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 15))
fig.suptitle('Feature Distribution in Training vs Test Set')

for i, column in enumerate(X.columns):
    sns.histplot(data=combined, x=column, hue='set', kde=True, ax=axes[i//2, i%2])
    axes[i//2, i%2].set_title(f'Distribution of {column}')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
